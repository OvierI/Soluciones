# %%
#SELECCIONANDO LOS ENTEROS n y m
import numpy as np 

#ingrese el número entero 
n = int(input("Por favor ingrese el valor de n="))

#si n está entre -30 y 30 y n es par, el programa sigue como se muestra
if (n in set(range(-30, 30, 1)) and n % 2 == 0):
    print("n par válido")
    m=(n/2-1)
    print("el m es", m)
    
    #GENERANDO LAS ENTRADAS DEL VECTOR k
   
    k = []
    
    while True:
            number_one = int(input("ingresa las componentes de k entre 1 y el m anterior ")) 
            k.append(number_one)
            print("k =", k)
            p = len(k)
            print("p =", p)
            if p >= m:
                break             
  
if (n in set(range(-30, 30, 1)) and n % 2 == 0):
    #print("n par válido")
    m=(n/2-1)
    #print("el m es", m)
    
    #GENERANDO LAS ENTRADAS DEL VECTOR l
    l = []
   
    while True:
            number_one2 = int(input("ingresa las componentes de l entre 1 y y el m anterior ")) 
            l.append(number_one2)
            print("l =", l)
            q = len(l)
            print("q =", q)
            if q >= m:
                break
        
      
   #se definen los vectores vp y vm
    
    vp=[l[0],k[0],k[1],-l[0],-k[0],-k[1]]
    vm=[0,0,l[0],l[1],-l[0],-l[1]]

    #np escribe los k, l, vp y vm como vectores
    k=np.array(k)
    l=np.array(l)
    vp=np.array(vp)
    vm=np.array(vm)

    #se hallan las soluciones que son CL de las soluciones individuales
    z=(vp*vm**2).sum()*vp-(vp**2*vm).sum()*vm 

    #se verifican las soluciones individuales

    print("la suma aritmética nos da", z.sum(), " y la suma de sus cubos nos da" ,(z**3).sum())
    
    
#si n está entre -30 y 30 y n es impar, el programa sigue como se muestra
if (n in set(range(-30, 30, 1)) and n% 2 != 0):
    print("n impar válido")
    m=(n-3)/2
    print("el m es", m)

    #GENERANDO LAS ENTRADAS DEL VECTOR k
   
    k = []
    
    while True:
            number_one = int(input("ingresa las componentes de k entre 1 y el m anterior ")) 
            k.append(number_one)
            print("k =", k)
            p = len(k)
            print("p =", p)
            if p >= m + 1:
                break
if (n in set(range(-30, 30, 1)) and n% 2 != 0):
    #print("n impar válido")
    m=(n-3)/2
    #print("el m es", m)
          
#GENERANDO LAS ENTRADAS DEL VECTOR l
    l = []
   
    while True:
            number_one2 = int(input("ingresa las componentes de l entre 1 y el m anterior ")) 
            l.append(number_one2)
            print("l =", l)
            q = len(l)
            print("q =", q)
            if q >= m:
                break
                
    #se definen los vectores up y um
    up=[0,k[0],k[1],k[2],k[3],k[4],k[5],k[6],-k[0],-k[1],-k[2],-k[3],-k[4],-k[5],-k[6]]
    um=[l[0],l[1],l[2],l[3],l[4],l[5],k[0],0,-l[0],-l[1],-l[2],-l[3],-l[4],-l[5],-k[0]]
    
    #np escribe los k, l, up y um como vectores
    k=np.array(k)
    l=np.array(l)
    up=np.array(up)
    um=np.array(um)
    
    #se hallan las soluciones que son CL de las soluciones individuales
    z=(up*um**2).sum()*up-(up**2*um).sum()*um
    
    #se verifican las soluciones individuales
    print("la suma aritmética nos da", z.sum(), " y la suma de sus cubos nos da" ,(z**3).sum())
    
#Cuando n no está entre -30 y 30    
else:    
    print("el n ingresado está fuera de rango")
# Out:
# Por favor ingrese el valor de n=6
# n par válido
# el m es 2.0
# ingresa las componentes de k entre 1 y el m anterior 1
# k = [1]
# p = 1
# ingresa las componentes de k entre 1 y el m anterior -2
# k = [1, -2]
# p = 2
# ingresa las componentes de l entre 1 y y el m anterior 1
# l = [1]
# q = 1
# ingresa las componentes de l entre 1 y y el m anterior 2
# l = [1, 2]
# q = 2
# la suma aritmética nos da 0  y la suma de sus cubos nos da 0
# el n ingresado está fuera de rango

# %% [markdown]
# #
